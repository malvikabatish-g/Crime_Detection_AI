# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 1 - Mount Google Drive
# ==========================================================

from google.colab import drive
import os

drive.mount('/content/drive')

print("Drive mounted successfully.")

DATASET_PATH = "/content/drive/MyDrive/OUR_DATASET/Combined_Dataset_v1"

if os.path.exists(DATASET_PATH):
    print("\nDataset found.")
    print(DATASET_PATH)
else:
    print("\nDataset NOT found.")
# Out:
# Mounted at /content/drive
# Drive mounted successfully.
#
# Dataset found.
# /content/drive/MyDrive/OUR_DATASET/Combined_Dataset_v1

# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 2 - Import Libraries
# ==========================================================

import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import models
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.callbacks import (
    EarlyStopping,
    ModelCheckpoint,
    ReduceLROnPlateau
)

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    ConfusionMatrixDisplay
)

# ----------------------------------------------------------
# Set Random Seed
# ----------------------------------------------------------

SEED = 42

random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

print("TensorFlow Version :", tf.__version__)
print("Num GPUs Available :", len(tf.config.list_physical_devices('GPU')))
# Out:
# TensorFlow Version : 2.20.0
# Num GPUs Available : 1

# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 3 - Configuration
# ==========================================================

# -----------------------------
# Dataset Paths
# -----------------------------

MODEL_NAME = "InceptionV3"

DATASET_PATH = "/content/drive/MyDrive/OUR_DATASET/Combined_Dataset_v1"

TRAIN_DIR = os.path.join(DATASET_PATH, "Train")
VAL_DIR = os.path.join(DATASET_PATH, "Validation")
TEST_DIR = os.path.join(DATASET_PATH, "Test")

# -----------------------------
# Image Parameters
# -----------------------------

IMAGE_SIZE = (299, 299)

BATCH_SIZE = 32

# -----------------------------
# Training Parameters
# -----------------------------

EPOCHS = 30

LEARNING_RATE = 1e-5

# -----------------------------
# Model Parameters
# -----------------------------

NUM_CLASSES = 6

CLASS_NAMES = sorted(os.listdir(TRAIN_DIR))

print("Classes Found:")
print(CLASS_NAMES)

# -----------------------------
# Save Paths
# -----------------------------

BASE_PATH = "/content/drive/MyDrive/OUR_DATASET"

REPORT_PATH = os.path.join(BASE_PATH, MODEL_NAME)

os.makedirs(REPORT_PATH, exist_ok=True)

MODEL_PATH = os.path.join(
    REPORT_PATH,
    "crime_detector_InceptionV3.keras"
)


print("\nConfiguration Loaded Successfully")
# Out:
# Classes Found:
# ['Abuse', 'Burglary', 'Fighting', 'Normal', 'RoadAccident', 'Snatching']
#
# Configuration Loaded Successfully

# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 4 - Load Dataset
# ==========================================================

train_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    label_mode="categorical",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=SEED
)

validation_dataset = tf.keras.utils.image_dataset_from_directory(
    VAL_DIR,
    labels="inferred",
    label_mode="categorical",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    TEST_DIR,
    labels="inferred",
    label_mode="categorical",
    image_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

print("\nDataset Loaded Successfully")

print("\nTraining batches   :", len(train_dataset))
print("Validation batches :", len(validation_dataset))
print("Test batches       :", len(test_dataset))
# Out:
# Found 7819 files belonging to 6 classes.
# Found 2487 files belonging to 6 classes.
# Found 2508 files belonging to 6 classes.
#
# Dataset Loaded Successfully
#
# Training batches   : 245
# Validation batches : 78
# Test batches       : 79

# %%
import os

for split in ["Train", "Validation", "Test"]:
    print(f"\n{split}")
    folder = os.path.join(DATASET_PATH, split)

    for cls in sorted(os.listdir(folder)):
        cls_path = os.path.join(folder, cls)
        if os.path.isdir(cls_path):
            count = len([
                f for f in os.listdir(cls_path)
                if f.lower().endswith((".jpg", ".jpeg", ".png"))
            ])
            print(f"{cls:15} {count}")
# Out:
# Train
# Abuse           1119
# Burglary        856
# Fighting        427
# Normal          1563
# RoadAccident    146
# Snatching       3708
#
# Validation
# Abuse           382
# Burglary        250
# Fighting        159
# Normal          768
# RoadAccident    98
# Snatching       830
#
# Test
# Abuse           496
# Burglary        166
# Fighting        82
# Normal          853
# RoadAccident    85
# Snatching       826

# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 5 - Optimize Dataset Performance
# ==========================================================

AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.prefetch(buffer_size=AUTOTUNE)

validation_dataset = validation_dataset.prefetch(buffer_size=AUTOTUNE)

test_dataset = test_dataset.prefetch(buffer_size=AUTOTUNE)

print("Dataset optimization completed.")
# Out:
# Dataset optimization completed.

# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 6 - Visualize Sample Images
# ==========================================================

sample_dataset = tf.keras.utils.image_dataset_from_directory(
    TRAIN_DIR,
    labels="inferred",
    label_mode="categorical",
    image_size=IMAGE_SIZE,
    batch_size=9,
    shuffle=True,
    seed=SEED
)

images, labels = next(iter(sample_dataset))

plt.figure(figsize=(10,10))

for i in range(9):

    plt.subplot(3,3,i+1)

    plt.imshow(images[i].numpy().astype("uint8"))

    plt.title(CLASS_NAMES[np.argmax(labels[i].numpy())])

    plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Found 7819 files belonging to 6 classes.

# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 7 - Build InceptionV3 Model
# ==========================================================

# -----------------------------
# Data Augmentation
# -----------------------------

data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.10),
    layers.RandomZoom(0.10),
    layers.RandomContrast(0.2),
    layers.RandomBrightness(0.2),
    layers.RandomTranslation(0.10, 0.10)
])

# -----------------------------
# InceptionV3 Base Model
# -----------------------------

base_model = InceptionV3(
    weights="imagenet",
    include_top=False,
    input_shape=(299, 299, 3)
)

# Freeze the pretrained layers
base_model.trainable = False

# -----------------------------
# Build Model
# -----------------------------

inputs = tf.keras.Input(shape=(299, 299, 3))

x = data_augmentation(inputs)

x = preprocess_input(x)

x = base_model(x, training=False)

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dropout(0.50)(x)

outputs = layers.Dense(
    NUM_CLASSES,
    activation="softmax"
)(x)

model = tf.keras.Model(inputs, outputs, name="CrimeDetection_InceptionV3")

print("Model Created Successfully")
# Out:
# Model Created Successfully

# %%
# ==========================================================
# Multiclass Crime Detection using
# Cell 8 - Compile Model
# ==========================================================

optimizer = tf.keras.optimizers.Adam(
    learning_rate=LEARNING_RATE
)

model.compile(
    optimizer=optimizer,
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

print("Model compiled successfully.\n")

model.summary()
# Out:
# Model compiled successfully.
# Model: "CrimeDetection_InceptionV3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential_1 (Sequential)       │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ true_divide_1 (TrueDivide)      │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ subtract_1 (Subtract)           │ (None, 299, 299, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ inception_v3 (Functional)       │ (None, 8, 8, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │        12,294 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,815,078 (83.22 MB)
#  Trainable params: 12,294 (48.02 KB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 9 - Training Callbacks
# ==========================================================

# Save the best model
checkpoint = ModelCheckpoint(
    filepath=MODEL_PATH,
    monitor="val_accuracy",
    save_best_only=True,
    verbose=1
)

# Stop training if validation loss doesn't improve
early_stopping = EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# Reduce learning rate when validation loss plateaus
reduce_lr = ReduceLROnPlateau(
    monitor="val_loss",
    factor=0.2,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

callbacks = [
    checkpoint,
    early_stopping,
    reduce_lr
]

print("Callbacks created successfully.")
# Out:
# Callbacks created successfully.

# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 10 - Compute Class Weights
# ==========================================================
from sklearn.utils.class_weight import compute_class_weight
import numpy as np

# Number of training images in each class.
# These values are obtained from the dataset builder summary
# and are used to compute balanced class weights.
class_counts = {
    "Abuse": 1119,
    "Burglary": 856,
    "Fighting": 427,
    "Normal": 1563,
    "RoadAccident": 146,
    "Snatching": 3708
}

# Build label array
train_labels = []

for idx, class_name in enumerate(CLASS_NAMES):
    train_labels.extend([idx] * class_counts[class_name])

train_labels = np.array(train_labels)

weights = compute_class_weight(
    class_weight="balanced",
    classes=np.unique(train_labels),
    y=train_labels
)

class_weights = {
    i: float(weights[i]) for i in range(len(weights))
}

print(class_weights)
# Out:
# {0: 1.1645814715519809, 1: 1.5223909657320873, 2: 3.051912568306011, 3: 0.8337598635103434, 4: 8.92579908675799, 5: 0.3514473211075153}

# %%
# ==========================================================
# Multiclass Crime Detection using InceptionV3
# Cell 11 - Train Model
# ==========================================================

history = model.fit(
    train_dataset,
    validation_data=validation_dataset,
    epochs=EPOCHS,
    callbacks=callbacks,
   # class_weight=class_weights,
    verbose=1
)

print("\nTraining Completed Successfully.")
# Out:
# Epoch 1/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.3489 - loss: 1.6977
# Epoch 1: val_accuracy improved from None to 0.34580, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 1: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 4289s 17s/step - accuracy: 0.3847 - loss: 1.6430 - val_accuracy: 0.3458 - val_loss: 1.6663 - learning_rate: 1.0000e-05
# Epoch 2/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.4421 - loss: 1.5310
# Epoch 2: val_accuracy improved from 0.34580 to 0.35183, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 2: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 137s 560ms/step - accuracy: 0.4460 - loss: 1.5164 - val_accuracy: 0.3518 - val_loss: 1.6451 - learning_rate: 1.0000e-05
# Epoch 3/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.4711 - loss: 1.4895
# Epoch 3: val_accuracy improved from 0.35183 to 0.35746, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 3: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 154s 610ms/step - accuracy: 0.4753 - loss: 1.4631 - val_accuracy: 0.3575 - val_loss: 1.6085 - learning_rate: 1.0000e-05
# Epoch 4/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.4748 - loss: 1.4192
# Epoch 4: val_accuracy improved from 0.35746 to 0.35867, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 4: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 134s 547ms/step - accuracy: 0.4827 - loss: 1.4074 - val_accuracy: 0.3587 - val_loss: 1.5831 - learning_rate: 1.0000e-05
# Epoch 5/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.5104 - loss: 1.3588
# Epoch 5: val_accuracy improved from 0.35867 to 0.36148, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 5: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 148s 605ms/step - accuracy: 0.5120 - loss: 1.3539 - val_accuracy: 0.3615 - val_loss: 1.5654 - learning_rate: 1.0000e-05
# Epoch 6/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.5310 - loss: 1.3082
# Epoch 6: val_accuracy improved from 0.36148 to 0.36630, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 6: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 134s 546ms/step - accuracy: 0.5352 - loss: 1.3043 - val_accuracy: 0.3663 - val_loss: 1.5461 - learning_rate: 1.0000e-05
# Epoch 7/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.5451 - loss: 1.2669
# Epoch 7: val_accuracy improved from 0.36630 to 0.37435, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 7: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 145s 593ms/step - accuracy: 0.5461 - loss: 1.2639 - val_accuracy: 0.3743 - val_loss: 1.5133 - learning_rate: 1.0000e-05
# Epoch 8/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.5579 - loss: 1.2359
# Epoch 8: val_accuracy improved from 0.37435 to 0.39003, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 8: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 134s 545ms/step - accuracy: 0.5647 - loss: 1.2155 - val_accuracy: 0.3900 - val_loss: 1.4916 - learning_rate: 1.0000e-05
# Epoch 9/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.5723 - loss: 1.2129
# Epoch 9: val_accuracy improved from 0.39003 to 0.40129, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 9: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 148s 604ms/step - accuracy: 0.5773 - loss: 1.1965 - val_accuracy: 0.4013 - val_loss: 1.4726 - learning_rate: 1.0000e-05
# Epoch 10/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.5736 - loss: 1.1722
# Epoch 10: val_accuracy improved from 0.40129 to 0.41335, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 10: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 130s 531ms/step - accuracy: 0.5829 - loss: 1.1602 - val_accuracy: 0.4133 - val_loss: 1.4611 - learning_rate: 1.0000e-05
# Epoch 11/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.6032 - loss: 1.1191
# Epoch 11: val_accuracy improved from 0.41335 to 0.42782, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 11: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 144s 539ms/step - accuracy: 0.6033 - loss: 1.1197 - val_accuracy: 0.4278 - val_loss: 1.4419 - learning_rate: 1.0000e-05
# Epoch 12/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.6160 - loss: 1.0895
# Epoch 12: val_accuracy improved from 0.42782 to 0.43707, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 12: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 142s 535ms/step - accuracy: 0.6180 - loss: 1.0821 - val_accuracy: 0.4371 - val_loss: 1.4331 - learning_rate: 1.0000e-05
# Epoch 13/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step - accuracy: 0.6246 - loss: 1.0587
# Epoch 13: val_accuracy improved from 0.43707 to 0.45316, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 13: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 148s 603ms/step - accuracy: 0.6264 - loss: 1.0541 - val_accuracy: 0.4532 - val_loss: 1.4190 - learning_rate: 1.0000e-05
# Epoch 14/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.6312 - loss: 1.0529
# Epoch 14: val_accuracy improved from 0.45316 to 0.46723, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 14: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 144s 586ms/step - accuracy: 0.6333 - loss: 1.0437 - val_accuracy: 0.4672 - val_loss: 1.4057 - learning_rate: 1.0000e-05
# Epoch 15/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.6402 - loss: 1.0327
# Epoch 15: val_accuracy improved from 0.46723 to 0.47768, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 15: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 144s 588ms/step - accuracy: 0.6381 - loss: 1.0328 - val_accuracy: 0.4777 - val_loss: 1.3981 - learning_rate: 1.0000e-05
# Epoch 16/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.6424 - loss: 1.0025
# Epoch 16: val_accuracy improved from 0.47768 to 0.48774, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 16: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 132s 536ms/step - accuracy: 0.6496 - loss: 0.9920 - val_accuracy: 0.4877 - val_loss: 1.3916 - learning_rate: 1.0000e-05
# Epoch 17/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.6600 - loss: 0.9782
# Epoch 17: val_accuracy improved from 0.48774 to 0.50060, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 17: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 131s 533ms/step - accuracy: 0.6606 - loss: 0.9730 - val_accuracy: 0.5006 - val_loss: 1.3740 - learning_rate: 1.0000e-05
# Epoch 18/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.6658 - loss: 0.9585
# Epoch 18: val_accuracy improved from 0.50060 to 0.50101, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 18: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 143s 585ms/step - accuracy: 0.6681 - loss: 0.9489 - val_accuracy: 0.5010 - val_loss: 1.3781 - learning_rate: 1.0000e-05
# Epoch 19/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.6680 - loss: 0.9473
# Epoch 19: val_accuracy improved from 0.50101 to 0.50422, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 19: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 132s 537ms/step - accuracy: 0.6794 - loss: 0.9338 - val_accuracy: 0.5042 - val_loss: 1.3761 - learning_rate: 1.0000e-05
# Epoch 20/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.6766 - loss: 0.9191
# Epoch 20: val_accuracy improved from 0.50422 to 0.51548, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 20: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 155s 591ms/step - accuracy: 0.6801 - loss: 0.9174 - val_accuracy: 0.5155 - val_loss: 1.3608 - learning_rate: 1.0000e-05
# Epoch 21/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.6921 - loss: 0.9100
# Epoch 21: val_accuracy did not improve from 0.51548
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 188s 533ms/step - accuracy: 0.6932 - loss: 0.8951 - val_accuracy: 0.5155 - val_loss: 1.3668 - learning_rate: 1.0000e-05
# Epoch 22/30
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.6983 - loss: 0.8720
# Epoch 22: val_accuracy improved from 0.51548 to 0.52312, saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
#
# Epoch 22: finished saving model to /content/drive/MyDrive/OUR_DATASET/InceptionV3/crime_detector_InceptionV3.keras
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 126s 513ms/step - accuracy: 0.6900 - loss: 0.8761 - val_accuracy: 0.5231 - val_loss: 1.3521 - learning_rate: 1.0000e-05
# Epoch 23/30
#  21/245 ━━━━━━━━━━━━━━━━━━━━ 1:39 445ms/step - accuracy: 0.7385 - loss: 0.8098

# %%
# Accuracy plot
plt.figure(figsize=(8,5))
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.grid(True)

plt.savefig(
    os.path.join(REPORT_PATH, "accuracy_plot.png"),
    dpi=300,
    bbox_inches="tight"
)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_4110/3559082485.py in <cell line: 0>()
#       1 # Accuracy plot
# ----> 2 plt.figure(figsize=(8,5))
#       3 plt.plot(history.history['accuracy'], label='Train Accuracy')
#       4 plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
#       5 plt.xlabel('Epoch')
#
# NameError: name 'plt' is not defined

# %%
# Loss plot
plt.figure(figsize=(8,5))
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.grid(True)

plt.savefig(
    os.path.join(REPORT_PATH, "loss_plot.png"),
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %%
#Validation Performance

val_loss, val_accuracy = model.evaluate(
    validation_dataset,
    verbose=1
)

print(f"Validation Loss     : {val_loss:.4f}")
print(f"Validation Accuracy : {val_accuracy:.4f}")
# Out:
# 78/78 ━━━━━━━━━━━━━━━━━━━━ 24s 303ms/step - accuracy: 0.3768 - loss: 1.5897
# Validation Loss     : 1.5897
# Validation Accuracy : 0.3768

# %%
#Test Evaluation
test_loss, test_accuracy = model.evaluate(
    test_dataset,
    verbose=1
)

print("Test Accuracy :", test_accuracy)
print("Test Loss :", test_loss)
# Out:
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 537s 7s/step - accuracy: 0.3620 - loss: 1.5510
# Test Accuracy : 0.3620414733886719
# Test Loss : 1.5509837865829468

# %%
#Summary of Results
print("="*40)
print("FINAL MODEL PERFORMANCE")
print("="*40)

print(f"Training Accuracy   : {history.history['accuracy'][-1]:.4f}")
print(f"Validation Accuracy : {val_accuracy:.4f}")
print(f"Test Accuracy       : {test_accuracy:.4f}")

print(f"\nTraining Loss       : {history.history['loss'][-1]:.4f}")
print(f"Validation Loss     : {val_loss:.4f}")
print(f"Test Loss           : {test_loss:.4f}")
# Out:
# ========================================
# FINAL MODEL PERFORMANCE
# ========================================
# Training Accuracy   : 0.5534
# Validation Accuracy : 0.3768
# Test Accuracy       : 0.3620
#
# Training Loss       : 1.2643
# Validation Loss     : 1.5897
# Test Loss           : 1.5510

# %%
import numpy as np

# Store true labels and predictions
y_true = []
y_pred = []

# Predict on the test dataset
for images, labels in test_dataset:
    predictions = model.predict(images, verbose=0)

    predicted_classes = np.argmax(predictions, axis=1)

    y_pred.extend(predicted_classes)
    y_true.extend(labels.numpy())

# Convert to numpy arrays
y_true = np.array(y_true)
y_pred = np.array(y_pred)

print("Number of test samples:", len(y_true))
print("Predictions generated successfully.")
# Out:
# Number of test samples: 2508
# Predictions generated successfully.

# %%
y_true = np.argmax(y_true, axis=1)

# %%
for i in range(10):
    print(
        f"Actual: {CLASS_NAMES[y_true[i]]} | "
        f"Predicted: {CLASS_NAMES[y_pred[i]]}"
    )

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred)

# Convert to DataFrame for readability
cm_df = pd.DataFrame(
    cm,
    index=CLASS_NAMES,
    columns=CLASS_NAMES
)

plt.figure(figsize=(14,12))

sns.heatmap(
    cm_df,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.xlabel("Predicted Class")
plt.ylabel("Actual Class")
plt.title("Confusion Matrix")

plt.tight_layout()

plt.savefig(
    os.path.join(REPORT_PATH, "confusion_matrix.png"),
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %%
from sklearn.metrics import classification_report

report = classification_report(
    y_true,
    y_pred,
    target_names=CLASS_NAMES,
    digits=4
)

print(report)

# %%
report_dict = classification_report(
    y_true,
    y_pred,
    target_names=CLASS_NAMES,
    output_dict=True
)

report_df = pd.DataFrame(report_dict).transpose()



report_df.head()

# %%
history_df.to_csv(
    os.path.join(REPORT_PATH, "training_history.csv"),
    index=False
)

report_df.to_csv(
    os.path.join(REPORT_PATH, "classification_report.csv"),
    index=True
)

cm_df.to_csv(
    os.path.join(REPORT_PATH, "confusion_matrix.csv"),
    index=True
)

model.save(MODEL_PATH)

print("All results saved successfully.")
